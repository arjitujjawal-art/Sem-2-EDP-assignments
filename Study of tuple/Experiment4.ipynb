# %% [markdown]
# #Practical 4 tuples
# ## arjit ujjawal
# ## prn - 25070123142
# ##batch - entc A2

# %%
##python tuples
#Access tuple
thistuples =  ("apples","banana","mango")
thistuples[1]="red"
print(thistuples)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2872925215.py in <cell line: 0>()
#       2 #Access tuple
#       3 thistuples =  ("apples","banana","mango")
# ----> 4 thistuples[1]="red"
#       5 print(thistuples)
#
# TypeError: 'tuple' object does not support item assignment

# %%
## Python Tuples
# Access Tuple Items

brands = ("Gucci", "Lifestyle", "Rolex", "Casio", "Titan", "Sonata")
print(brands[3])

# %%
t1=(34,45,56)
t2=(23,45,32)
t3=t1+t2
print(t3)
# Out:
# (34, 45, 56, 23, 45, 32)

# %%
t1=(45,56,78,98,54,45)
t5=(34,23)
t5+=t1
print(t5)
# Out:
# (34, 23, 45, 56, 78, 98, 54, 45)

# %%
t1=(45,56,78,98,54,45)
t5=(34,23)
print("before",id(t5))
t5+=t1
print(t5)
print("after",id(t5))
# Out:
# before 139422871516416
# (34, 23, 45, 56, 78, 98, 54, 45)
# after 139423271368544

# %%
# Problem Statement - 1 - Student Mark Analysis

data = ("Maths", 90, "A")
print("Subject: ", data[0])
print("Marks: ", data[1])
print("Grade: ", data[2])
if (data[1] > 75):
  print("The Student has Acheieved 'Distinction'")
# Out:
# Subject:  Maths
# Marks:  90
# Grade:  A
# The Student has Acheieved 'Distinction'

# %%
# Problem Statement - 2 Employee Attendance

attendance = ("P", "P", "P", "A", "P", "P")
print("Total Present Days: ", attendance.count("P"), "\n")
print("Total Absent Days: ", attendance.count("A"),"\n")
if ("A" in attendance):
  print("The Employee is Absent atleast once")
else:
  print("The Employee is Present")
# Out:
# Total Present Days:  5
#
# Total Absent Days:  1
#
# The Employee is Absent atleast once
