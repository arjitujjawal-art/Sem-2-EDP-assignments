# %% [markdown]
# # Unit - 4
# # Experiment 16: Basic Charts and Visual Encoding
#
# ### Name: Arjit
# ### PRN: 25070123142
# ### Batch: ENTC - A2

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = {
    'Days' : ['Mon', 'Tue', 'Wed', 'Thu', 'Fri'],
    'Study_Hours' : [2, 3, 2.3, 4, 3.5],
    'Marks' : [70, 80, 85, 55, 90],
    'Attendance' : [60, 70, 65, 80, 75],
    'Sleep_Hours': [6,7,8,7,6],
    'Assignments_Completed' : [1, 2, 1, 3, 2]
}

df = pd.DataFrame(data)
df
# Out:
#   Days  Study_Hours  Marks  Attendance  Sleep_Hours  Assignments_Completed
# 0  Mon          2.0     70          60            6                      1
# 1  Tue          3.0     80          70            7                      2
# 2  Wed          2.3     85          65            8                      1
# 3  Thu          4.0     55          80            7                      3
# 4  Fri          3.5     90          75            6                      2

# %%
# 1.Line Chart (Trend)

plt.plot(df['Days'], df['Study_Hours'], marker = 'o')

plt.title('Study Hours Trend')
plt.xlabel('Days')
plt.ylabel('Study Hours')

plt.show()

# %%
# Advanced Line Chart

plt.figure(figsize = (7,7))

plt.plot(df['Days'] , df['Study_Hours'], marker = 'o', color = 'blue', label = 'Study_Hours')

plt.plot(df['Days'] , df['Marks'], marker = 's', color = 'red', label = 'Marks')

plt.title('Study Hours and Marks Trend')
plt.xlabel('Days')
plt.ylabel('Study Hours/Marks')
plt.legend()

plt.show()

# %%
# 2. Bar Chart

plt.bar(df['Days'], df['Marks'], color = 'violet')

plt.title('Marks Comparison')
plt.xlabel('Days')
plt.ylabel('Marks')

plt.show()

# %%
# Advanced Bar Graph

bars = plt.bar(df['Days'], df['Marks'], color = 'bisque')

for bar in bars:
  y = bar.get_height()
  plt.text(bar.get_x() + bar.get_width() / 2, y, str(y), ha = 'center', va = 'bottom')

plt.title("Marks Comparison")
plt.xlabel("Days")
plt.ylabel("Marks")

plt.grid(axis = 'y') # Adds Horizontal grid for readability

plt.show()

# %%
# 3.Histogram (distribution)

# shows how the values are spread

data = {
    'Marks' : [50, 60, 55, 70, 65, 75, 80, 85, 90, 45, 68, 72, 77, 82, 88, 67, 90, 95, 67]
}

df = pd.DataFrame(data)

plt.hist(df['Marks'] , bins = 15, color = 'paleturquoise')
plt.title('Marks Distribution')
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.show()

# %%
# 4. Scatter Plot (Relationship)

import matplotlib.pyplot as plt

plt.scatter(df['Study_Hours'], df['Marks'], color = 'slateblue')

plt.title("Study Hours vs Marks")
plt.xlabel("Study Hours")
plt.ylabel("Marks")

plt.show()

# %%
# Conditional Scatter Plot
#Example Category

df['Result'] = ['Pass', 'Fail', 'Pass', 'Fail', 'Fail']

colors = ['red' if r == 'Fail' else 'green' for r in df['Result']]
plt.scatter(df['Study_Hours'], df['Marks'], c = colors)

plt.title("Study Hours vs Marks (Result-wise)")
plt.xlabel("Study Hours")
plt.ylabel("Marks")

plt.show()

# %% [markdown]
# # Seaborn Graph Visualization

# %%
# Histogram (Defaut border line and advance functions of matplotlib are default here)

sns.histplot(df['Sales'], bins = 5)
plt.title("Seaborn Histogram")
plt.show()

# %% [markdown]
# # Dataset - 2

# %%
# Dataset - 2

data = {
    'Day' : ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Wed', 'Thu', 'Sat', 'Sun'],
    'Region' : ['North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North'],
    'Sales' : [200, 220, 350, 390, 250, 270, 290, 400, 390],
    'Profit' : [20, 45, 60, 70, 35, 50, 20, 60, 65],
    'Customers' : [20, 30, 25, 40, 35, 40, 45, 47, 33],
    'Category' : ['Electronics', 'Clothing', 'Electronics', 'Food', 'Electronics', 'Clothing', 'Food', 'Clothing', 'Electronics']
}

df = pd.DataFrame(data)
df
# Out:
#    Day Region  Sales  Profit  Customers     Category
# 0  Mon  North    200      20         20  Electronics
# 1  Tue  South    220      45         30     Clothing
# 2  Wed   East    350      60         25  Electronics
# 3  Thu   West    390      70         40         Food
# 4  Fri  North    250      35         35  Electronics
# 5  Wed  South    270      50         40     Clothing
# 6  Thu   East    290      20         45         Food
# 7  Sat   West    400      60         47     Clothing
# 8  Sun  North    390      65         33  Electronics

# %%
# 1. Line Chart

plt.figure(figsize = (7,7))

plt.plot(df['Profit'] , df['Day'], marker = 'o', color = 'blue', label = 'Study_Hours')

plt.plot(df['Profit'] , df['Region'], marker = 's', color = 'red', label = 'Marks')

plt.title('Trends of Profit in different days and regions')
plt.xlabel('Profit')
plt.ylabel('Day / Region')
plt.legend()

plt.show()

# %%
# 2. Bar Graph

bars = plt.bar(df['Category'], df['Sales'], color = 'bisque')

for bar in bars:
  y = bar.get_height()
  plt.text(bar.get_x() + bar.get_width() / 2, y, str(y), ha = 'center', va = 'bottom')

plt.title("Category wise Sales Analysis")
plt.xlabel("Category")
plt.ylabel("Sales")

plt.grid(axis = 'y') # Adds Horizontal grid for readability

plt.show()

# %%
# 2. Bar Graph

bars = plt.bar(df['Region'], df['Sales'], color = 'paleturquoise')

for bar in bars:
  y = bar.get_height()
  plt.text(bar.get_x() + bar.get_width() / 2, y, str(y), ha = 'center', va = 'bottom')

plt.title("Category wise Sales Analysis")
plt.xlabel("Region")
plt.ylabel("Sales")

plt.grid(axis = 'y') # Adds Horizontal grid for readability

plt.show()

# %%
# 3.Histogram

data = {
    'Sales' : [50, 60, 55, 70, 65, 48, 99, 20, 30, 30, 75, 80, 85, 90, 45,20,  68, 72, 77, 82, 88, 67, 90, 95, 67]
}

df1 = pd.DataFrame(data)

plt.hist(df1['Sales'] , bins = 15, color = 'paleturquoise')
plt.title('Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
# 4. Scatter Plot (Relationship)

import matplotlib.pyplot as plt

plt.scatter(df['Region'], df['Sales'], color = 'slateblue')

plt.title("Region vs Sales")
plt.xlabel("Region")
plt.ylabel("Sales")

plt.show()

# %%
# Line Plot

sns.lineplot(x = 'Days', y = 'Result', data = df)
plt.title('Seaborn Line Plot')
plt.show()
