# %% [markdown]
# #Study of Pandas lib in python
# #Experiment 9
# #name - arjit
# #prn - 25070123142

# %%
import pandas as pd
s = pd.Series([10,20,30,40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
#Create of dataFrame
data={"name":["A","B","C","ARJIT"],
      "marks":[34,54,23,12]}
df = pd.DataFrame(data)
df
# Out:
#     name  marks
# 0      A     34
# 1      B     54
# 2      C     23
# 3  ARJIT     12

# %%
# Find the structure of the DataFrame
df.shape
# Out:
# (4, 2)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 8

# %%
#Display Column Names
df.columns
# Out:
# Index(['name', 'marks'], dtype='object')

# %%
#Check Data types of each Column
df.dtypes
# Out:
# name     object
# marks     int64
# dtype: object

# %%
#access individual Column
df["name"]
# Out:
# 0        A
# 1        B
# 2        C
# 3    ARJIT
# Name: name, dtype: object

# %%
df.loc[1]
# Out:
# name      B
# marks    54
# Name: 1, dtype: object

# %%
df.iloc[0]
# Out:
# name      A
# marks    34
# Name: 0, dtype: object

# %%
#Add new column
df["Grade"]=["Distinction","First class","not worthy to exist","should die"]
df
# Out:
#     name  marks                Grade
# 0      A     34          Distinction
# 1      B     54          First class
# 2      C     23  not worthy to exist
# 3  ARJIT     12           should die

# %%
#change the value
df.loc[0,"marks"]=89
df
# Out:
#     name  marks
# 0      A     89
# 1      B     54
# 2      C     23
# 3  ARJIT     12

# %%
#delete the column
df.drop("marks",axis=1,inplace=True)
df
# Out:
#     name
# 0      A
# 1      B
# 2      C
# 3  ARJIT

# %%
#Perform Basic  Statistical Analysis
mean1=df["marks"].mean()
mean1
# Out:
# np.float64(30.75)

# %%
min1=df["marks"].min()
min1
# Out:
# 12

# %%
max1=df["marks"].max()
max1
# Out:
# 54

# %%
#apply conditon (filtering)
df[df["marks"]>80]
# Out:
#   name  marks
# 0    A     89
