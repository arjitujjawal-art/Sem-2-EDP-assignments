# %% [markdown]
# ## Basic Programs - Experiment-2
# ### arjit ujjawal
# ### prn - 25070123142

# %%
print("hello world")
# Out:
# hello world

# %%
#variable
x = 5
y ="Hello world"
print (x)
print (y)
# Out:
# 5
# Hello world

# %%
# 1 physical statements and 3 logical statements

print("Hello"); print("How are you?"); print("Bye bye!")
# Out:
# Hello
# How are you?
# Bye bye!

# %%
#many values to multiple varibles
x , y , z = "orange","banana","cherry"
print (x)
print (y)
print (z)
# Out:
# orange
# banana
# cherry

# %%
#basic arthemethic operation
a = 10
b = 5
print("addition=",a+b)
# Out:
# addition= 15

# %%
#Understanding the data type
x=19
y=3.23
z="hi my name is raj"
A= True
c= 3+2j
print(type(c))
print(type(x))
print(type(y))
print(type(A))
# Out:
# <class 'complex'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
#taking input from the user
name =str(input())
age =int(input())
print (name)
print (age)
# Out:
# arjit
# 45
# arjit
# 45

# %%
#simple calculator
x=int(input("enter the number"))
y=int(input("enter the number"))
print(sum([x,y]))
# Out:
# enter the number666
# enter the number666666
# 667332

# %%
# student marks

phy = int(input("Enter your Physics marks: "))
chem = int(input("Enter your Chemistry marks: "))
bio = int(input("Enter your Biology marks:"))
eng = int(input("Enter your English marks: "))
math = int(input("Enter your Mathematics marks: "))
sum = phy + chem + bio + eng + math
print("Your total marks are: ", sum)
print("Your Average mark is: ", sum / 5 )
# Out:
# Enter your Physics marks: 34
# Enter your Chemistry marks: 43
# Enter your Biology marks:23
# Enter your English marks: 11
# Enter your Mathematics marks: 556
# Your total marks are:  667
# Your Average mark is:  133.4

# %%
# Area of Circle

r = float(input("Enter the radius of the circle: "))
area = 3.14 * r * r
print("The area of the circle of the given radius is: ", area)
# Out:
# Enter the radius of the circle: 2
# The area of the circle of the given radius is:  12.56

# %%
# Area of a Rectangle

l  = float(input("Enter the length of the rectangle: "))
b = float(input("Enter the breadth of the rectangle: "))
area = l * b
print("The area of the rectangle is: ", area)
# Out:
# Enter the length of the rectangle: 25
# Enter the breadth of the rectangle: 20
# The area of the rectangle is:  500.0

# %%
# Perimeter of Rectangle

l  = float(input("Enter the length of the rectangle: "))
b = float(input("Enter the breadth of the rectangle: "))
perimeter = 2 * (l + b)
print("The perimeter of the rectangle is: ", perimeter)
# Out:
# Enter the length of the rectangle: 20
# Enter the breadth of the rectangle: 22
# The perimeter of the rectangle is:  84.0
